# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#공부시간 X와 성적 Y의 리스트를 만듭니다.
data = [[2, 0], [4, 0], [6, 0], [8, 1], [10, 1], [12, 1], [14, 0]]

x_data = [i[0] for i in data]
y_data = [i[1] for i in data]

#그래프로 나타내 봅니다.
plt.scatter(x_data, y_data)
plt.xlim(0, 15)
plt.ylim(-.1, 1.1)
# Out:
# (-0.1, 1.1)

# %%
# 기울기 a와 절편 b의 값을 초기화 합니다.
a = 0
b = 0

#학습률을 정합니다.
lr = 0.05 

#시그모이드 함수를 정의합니다.
def sigmoid(x):
    return 1 / (1 + np.e ** (-x))

#경사 하강법을 실행합니다.
for i in range(2001):
    for x_data, y_data in data:
        a_diff = x_data*(sigmoid(a*x_data + b) - y_data) 
        b_diff = sigmoid(a*x_data + b) - y_data
        a = a - lr * a_diff
        b = b - lr * b_diff
        if i % 1000 == 0:    # 1000번 반복될 때마다 각 x_data값에 대한 현재의 a값, b값을 출력합니다.
            print("epoch=%.f, 기울기=%.04f, 절편=%.04f" % (i, a, b))
# Out:
# epoch=0, 기울기=-0.0500, 절편=-0.0250
# epoch=0, 기울기=-0.1388, 절편=-0.0472
# epoch=0, 기울기=-0.2268, 절편=-0.0619
# epoch=0, 기울기=0.1201, 절편=-0.0185
# epoch=0, 기울기=0.2374, 절편=-0.0068
# epoch=0, 기울기=0.2705, 절편=-0.0040
# epoch=0, 기울기=-0.4140, 절편=-0.0529
# epoch=1000, 기울기=-0.5451, 절편=1.0009
# epoch=1000, 기울기=-0.5922, 절편=0.9892
# epoch=1000, 기울기=-0.6136, 절편=0.9856
# epoch=1000, 기울기=-0.2214, 절편=1.0346
# epoch=1000, 기울기=0.1610, 절편=1.0729
# epoch=1000, 기울기=0.1893, 절편=1.0752
# epoch=1000, 기울기=-0.4942, 절편=1.0264
# epoch=2000, 기울기=-0.5451, 절편=1.0009
# epoch=2000, 기울기=-0.5922, 절편=0.9892
# epoch=2000, 기울기=-0.6136, 절편=0.9856
# epoch=2000, 기울기=-0.2214, 절편=1.0346
# epoch=2000, 기울기=0.1610, 절편=1.0729
# epoch=2000, 기울기=0.1893, 절편=1.0752
# epoch=2000, 기울기=-0.4942, 절편=1.0264

# %%
# 앞서 구한 기울기와 절편을 이용해 그래프를 그려 봅니다.
x_data = [i[0] for i in data]
y_data = [i[1] for i in data]

plt.scatter(x_data, y_data)
plt.xlim(0, 15)
plt.ylim(-.1, 1.1)
x_range = (np.arange(0, 15, 0.1)) #그래프로 나타낼 x값의 범위를 정합니다.
plt.plot(np.arange(0, 15, 0.1), np.array([sigmoid(a*x + b) for x in x_range]))
plt.show()

# %%
#UPDATE

#책의 코드는 각각의 x에 대한 기울기, 절편의 변화가 epoch마다 모두 출력 되어 이를 확인하게 끔 되어 있습니다.
#평균값을 구해 하나의 기울기와 절편을 출력하고, 1000 epoch마다 그래프를 그리면 다음과 같습니다.  

# 데이터 선언 
x = [i[0] for i in data]
y = [i[1] for i in data]
x_data = np.array(x)
y_data = np.array(y)

# 위에 계산된 a와 b의 값이 다시 사용되지 않기 위해 각각 0으로 초기화 합니다.
a = 0
b = 0

loss = []
epoch = []

#경사 하강법을 실행합니다.
for i in range(10001):
    
     #실습과제2
    y_hat = sigmoid(a * x_data + b)  #y를 구하는 식을 세웁니다
    mse = ((y_data-y_hat)**2).mean()
    loss.append(mse)
    epoch.append(i)

    #

    a_diff = (1/len(x_data))*sum(x_data*(sigmoid(a*x_data + b) - y_data)) 
    b_diff = (1/len(x_data))*sum(sigmoid(a*x_data + b) - y_data)
    a = a - lr * a_diff
    b = b - lr * b_diff
    
    if i % 1000 == 0:    # 1000번 반복될 때마다 각 x_data값에 대한 현재의 a값, b값을 출력합니다.
        print("epoch=%.f, 기울기=%.04f, 절편=%.04f, mse: %.04f" % (i, a, b, mse))
        plt.scatter(x_data, y_data)
        plt.xlim(0, 15)
        plt.ylim(-.1, 1.1)
        x_range = (np.arange(0, 15, 0.1)) #그래프로 나타낼 x값의 범위를 정합니다.
        plt.plot(np.arange(0, 15, 0.1), np.array([sigmoid(a*x + b) for x in x_range]))
        plt.show()
# Out:
# epoch=0, 기울기=0.0143, 절편=-0.0036, mse: 0.2500
# epoch=1000, 기울기=0.2108, 절편=-1.9640, mse: 0.2004
# epoch=2000, 기울기=0.2412, 절편=-2.2687, mse: 0.2004
# epoch=3000, 기울기=0.2473, 절편=-2.3308, mse: 0.2005
# epoch=4000, 기울기=0.2487, 절편=-2.3442, mse: 0.2006
# epoch=5000, 기울기=0.2489, 절편=-2.3470, mse: 0.2006
# epoch=6000, 기울기=0.2490, 절편=-2.3477, mse: 0.2006
# epoch=7000, 기울기=0.2490, 절편=-2.3478, mse: 0.2006
# epoch=8000, 기울기=0.2490, 절편=-2.3478, mse: 0.2006
# epoch=9000, 기울기=0.2490, 절편=-2.3478, mse: 0.2006
# epoch=10000, 기울기=0.2490, 절편=-2.3479, mse: 0.2006

# %%
#UPDATE

#책의 코드는 각각의 x에 대한 기울기, 절편의 변화가 epoch마다 모두 출력 되어 이를 확인하게 끔 되어 있습니다.
#평균값을 구해 하나의 기울기와 절편을 출력하고, 1000 epoch마다 그래프를 그리면 다음과 같습니다.  

# 데이터 선언 
x = [i[0] for i in data]
y = [i[1] for i in data]
x_data = np.array(x)
y_data = np.array(y)

# 위에 계산된 a와 b의 값이 다시 사용되지 않기 위해 각각 0으로 초기화 합니다.
a = 0
b = 0

loss = []
epoch = []

#경사 하강법을 실행합니다.
for i in range(10001):
    
     #실습과제2
    y_hat = sigmoid(a * x_data + b)  #y를 구하는 식을 세웁니다
    mse = ((y_data-y_hat)**2).mean()
    loss.append(mse)
    epoch.append(i)

    #

    a_diff = (1/len(x_data))*sum(x_data*(sigmoid(a*x_data + b) - y_data)) 
    b_diff = (1/len(x_data))*sum(sigmoid(a*x_data + b) - y_data)
    a = a - lr * a_diff
    b = b - lr * b_diff      
    
    if i % 1000 == 0:    # 1000번 반복될 때마다 각 x_data값에 대한 현재의 a값, b값을 출력합니다.
        print("epoch=%.f, 기울기=%.04f, 절편=%.04f, mse: %.04f" % (i, a, b, mse))
        plt.xlim(0, 10001)
        plt.ylim(0, 0.25 ,0.25)
        plt.xlabel('epoch(Loop Num)')
        plt.ylabel('loss[]')
        x_range = (np.arange(0, 15, 0.1)) #그래프로 나타낼 x값의 범위를 정합니다.
        #plt.scatter(i, loss[i])
        #plt.plot(np.arange(0, 15, 0.1), np.array([ sigmoid(a * x_data + b) for x_data in x_range]))
        
        plt.plot(epoch, loss)
        #plt.show()
# Out:
# epoch=0, 기울기=0.0143, 절편=-0.0036, mse: 0.2500
# epoch=1000, 기울기=0.2108, 절편=-1.9640, mse: 0.2004
# epoch=2000, 기울기=0.2412, 절편=-2.2687, mse: 0.2004
# epoch=3000, 기울기=0.2473, 절편=-2.3308, mse: 0.2005
# epoch=4000, 기울기=0.2487, 절편=-2.3442, mse: 0.2006
# epoch=5000, 기울기=0.2489, 절편=-2.3470, mse: 0.2006
# epoch=6000, 기울기=0.2490, 절편=-2.3477, mse: 0.2006
# epoch=7000, 기울기=0.2490, 절편=-2.3478, mse: 0.2006
# epoch=8000, 기울기=0.2490, 절편=-2.3478, mse: 0.2006
# epoch=9000, 기울기=0.2490, 절편=-2.3478, mse: 0.2006
# epoch=10000, 기울기=0.2490, 절편=-2.3479, mse: 0.2006

# %%
for i in range(7):
    y_hat = sigmoid(a * x[i] + b)  #y를 구하는 식을 세웁니다
    mse = ((y[i]-y_hat)**2).mean()
    print("Input: %.1f, Real: %.1f, Expect: %.4f" %(x[i], y[i], mse))
# Out:
# Input: 2.0, Real: 0.0, Expect: 0.0206
# Input: 4.0, Real: 0.0, Expect: 0.0456
# Input: 6.0, Real: 0.0, Expect: 0.0933
# Input: 8.0, Real: 1.0, Expect: 0.3411
# Input: 10.0, Real: 1.0, Expect: 0.2156
# Input: 12.0, Real: 1.0, Expect: 0.1215
# Input: 14.0, Real: 0.0, Expect: 0.5650
