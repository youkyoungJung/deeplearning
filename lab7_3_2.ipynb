# %%
from keras.models import Sequential
from keras.layers.core import Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint,EarlyStopping

import pandas as pd
import numpy
import tensorflow as tf
import os

# seed 값 설정
seed = 0
numpy.random.seed(seed)
tf.random.set_seed(3)

df = pd.read_csv('../Downloads/080228-master/080228-master/deeplearning/dataset/sonar.csv', header=None)

'''
print(df.info())
print(df.head())
'''

dataset = df.values
X = dataset[:,0:60].astype(float)
Y_obj = dataset[:,60]

e = LabelEncoder()
e.fit(Y_obj)
Y = e.transform(Y_obj)

# 학습 셋과 테스트 셋의 구분
#X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=seed)

model = Sequential()
model.add(Dense(24,  input_dim=60, activation='relu'))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='mean_squared_error',
            optimizer='adam',
            metrics=['accuracy'])

# 모델 저장 폴더 설정
MODEL_DIR = './model/'
if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

modelpath="./model/{epoch:02d}-{val_loss:.4f}.hdf5"

# 모델 업데이트 및 저장
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)

# 학습 자동 중단 설정
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=100)

history = model.fit(X, Y, validation_split=0.1, epochs=3500, batch_size=500, verbose=0, callbacks=[early_stopping_callback,checkpointer])


# y_vloss에 테스트셋으로 실험 결과의 오차 값을 저장
y_vloss=history.history['val_loss']

# y_acc 에 학습 셋으로 측정한 정확도의 값을 저장
y_acc=history.history['accuracy']

y_vacc=history.history['val_accuracy']

# # 모델 실행 및 저장
# model.fit(X, Y, validation_split=0.2, epochs=200, batch_size=200, verbose=0, callbacks=[checkpointer])

# model.fit(X_train, Y_train, epochs=130, batch_size=5)

# # 테스트셋에 모델 적용
# print("\n Test Accuracy: %.4f" % (model.evaluate(X_test, Y_test)[1]))
# Out:
# C:\Users\yyk834\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\yyk834\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\yyk834\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\yyk834\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\yyk834\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\yyk834\Anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Epoch 00001: val_loss improved from inf to 0.29754, saving model to ./model\01-0.2975.hdf5
#
# Epoch 00002: val_loss improved from 0.29754 to 0.29558, saving model to ./model\02-0.2956.hdf5
#
# Epoch 00003: val_loss improved from 0.29558 to 0.29394, saving model to ./model\03-0.2939.hdf5
#
# Epoch 00004: val_loss improved from 0.29394 to 0.29303, saving model to ./model\04-0.2930.hdf5
#
# Epoch 00005: val_loss improved from 0.29303 to 0.29277, saving model to ./model\05-0.2928.hdf5
#
# Epoch 00006: val_loss did not improve from 0.29277
#
# Epoch 00007: val_loss did not improve from 0.29277
#
# Epoch 00008: val_loss did not improve from 0.29277
#
# Epoch 00009: val_loss did not improve from 0.29277
#
# Epoch 00010: val_loss did not improve from 0.29277
#
# Epoch 00011: val_loss did not improve from 0.29277
#
# Epoch 00012: val_loss did not improve from 0.29277
#
# Epoch 00013: val_loss did not improve from 0.29277
#
# Epoch 00014: val_loss did not improve from 0.29277
#
# Epoch 00015: val_loss did not improve from 0.29277
#
# Epoch 00016: val_loss did not improve from 0.29277
#
# Epoch 00017: val_loss did not improve from 0.29277
#
# Epoch 00018: val_loss did not improve from 0.29277
#
# Epoch 00019: val_loss did not improve from 0.29277
#
# Epoch 00020: val_loss did not improve from 0.29277
#
# Epoch 00021: val_loss did not improve from 0.29277
#
# Epoch 00022: val_loss did not improve from 0.29277
#
# Epoch 00023: val_loss did not improve from 0.29277
#
# Epoch 00024: val_loss did not improve from 0.29277
#
# Epoch 00025: val_loss did not improve from 0.29277
#
# Epoch 00026: val_loss did not improve from 0.29277
#
# Epoch 00027: val_loss did not improve from 0.29277
#
# Epoch 00028: val_loss did not improve from 0.29277
#
# Epoch 00029: val_loss did not improve from 0.29277
#
# Epoch 00030: val_loss did not improve from 0.29277
#
# Epoch 00031: val_loss did not improve from 0.29277
#
# Epoch 00032: val_loss did not improve from 0.29277
#
# Epoch 00033: val_loss did not improve from 0.29277
#
# Epoch 00034: val_loss did not improve from 0.29277
#
# Epoch 00035: val_loss did not improve from 0.29277
#
# Epoch 00036: val_loss did not improve from 0.29277
#
# Epoch 00037: val_loss did not improve from 0.29277
#
# Epoch 00038: val_loss did not improve from 0.29277
#
# Epoch 00039: val_loss did not improve from 0.29277
#
# Epoch 00040: val_loss did not improve from 0.29277
#
# Epoch 00041: val_loss did not improve from 0.29277
#
# Epoch 00042: val_loss did not improve from 0.29277
#
# Epoch 00043: val_loss did not improve from 0.29277
#
# Epoch 00044: val_loss did not improve from 0.29277
#
# Epoch 00045: val_loss did not improve from 0.29277
#
# Epoch 00046: val_loss did not improve from 0.29277
#
# Epoch 00047: val_loss did not improve from 0.29277
#
# Epoch 00048: val_loss did not improve from 0.29277
#
# Epoch 00049: val_loss did not improve from 0.29277
#
# Epoch 00050: val_loss did not improve from 0.29277
#
# Epoch 00051: val_loss did not improve from 0.29277
#
# Epoch 00052: val_loss did not improve from 0.29277
#
# Epoch 00053: val_loss did not improve from 0.29277
#
# Epoch 00054: val_loss did not improve from 0.29277
#
# Epoch 00055: val_loss did not improve from 0.29277
#
# Epoch 00056: val_loss did not improve from 0.29277
#
# Epoch 00057: val_loss did not improve from 0.29277
#
# Epoch 00058: val_loss did not improve from 0.29277
#
# Epoch 00059: val_loss did not improve from 0.29277
#
# Epoch 00060: val_loss did not improve from 0.29277
#
# Epoch 00061: val_loss did not improve from 0.29277
#
# Epoch 00062: val_loss did not improve from 0.29277
#
# Epoch 00063: val_loss did not improve from 0.29277
#
# Epoch 00064: val_loss improved from 0.29277 to 0.29150, saving model to ./model\64-0.2915.hdf5
#
# Epoch 00065: val_loss improved from 0.29150 to 0.28933, saving model to ./model\65-0.2893.hdf5
#
# Epoch 00066: val_loss improved from 0.28933 to 0.28747, saving model to ./model\66-0.2875.hdf5
#
# Epoch 00067: val_loss improved from 0.28747 to 0.28581, saving model to ./model\67-0.2858.hdf5
#
# Epoch 00068: val_loss improved from 0.28581 to 0.28398, saving model to ./model\68-0.2840.hdf5
#
# Epoch 00069: val_loss improved from 0.28398 to 0.28173, saving model to ./model\69-0.2817.hdf5
#
# Epoch 00070: val_loss improved from 0.28173 to 0.27901, saving model to ./model\70-0.2790.hdf5
#
# Epoch 00071: val_loss improved from 0.27901 to 0.27616, saving model to ./model\71-0.2762.hdf5
#
# Epoch 00072: val_loss improved from 0.27616 to 0.27336, saving model to ./model\72-0.2734.hdf5
#
# Epoch 00073: val_loss improved from 0.27336 to 0.27046, saving model to ./model\73-0.2705.hdf5
#
# Epoch 00074: val_loss improved from 0.27046 to 0.26760, saving model to ./model\74-0.2676.hdf5
#
# Epoch 00075: val_loss improved from 0.26760 to 0.26499, saving model to ./model\75-0.2650.hdf5
#
# Epoch 00076: val_loss improved from 0.26499 to 0.26249, saving model to ./model\76-0.2625.hdf5
#
# Epoch 00077: val_loss improved from 0.26249 to 0.26021, saving model to ./model\77-0.2602.hdf5
#
# Epoch 00078: val_loss improved from 0.26021 to 0.25808, saving model to ./model\78-0.2581.hdf5
#
# Epoch 00079: val_loss improved from 0.25808 to 0.25589, saving model to ./model\79-0.2559.hdf5
#
# Epoch 00080: val_loss improved from 0.25589 to 0.25393, saving model to ./model\80-0.2539.hdf5
#
# Epoch 00081: val_loss improved from 0.25393 to 0.25225, saving model to ./model\81-0.2523.hdf5
#
# Epoch 00082: val_loss improved from 0.25225 to 0.25089, saving model to ./model\82-0.2509.hdf5
#
# Epoch 00083: val_loss improved from 0.25089 to 0.24975, saving model to ./model\83-0.2497.hdf5
#
# Epoch 00084: val_loss improved from 0.24975 to 0.24833, saving model to ./model\84-0.2483.hdf5
#
# Epoch 00085: val_loss improved from 0.24833 to 0.24661, saving model to ./model\85-0.2466.hdf5
#
# Epoch 00086: val_loss improved from 0.24661 to 0.24436, saving model to ./model\86-0.2444.hdf5
#
# Epoch 00087: val_loss improved from 0.24436 to 0.24178, saving model to ./model\87-0.2418.hdf5
#
# Epoch 00088: val_loss improved from 0.24178 to 0.23912, saving model to ./model\88-0.2391.hdf5
#
# Epoch 00089: val_loss improved from 0.23912 to 0.23681, saving model to ./model\89-0.2368.hdf5
#
# Epoch 00090: val_loss improved from 0.23681 to 0.23517, saving model to ./model\90-0.2352.hdf5
#
# Epoch 00091: val_loss improved from 0.23517 to 0.23404, saving model to ./model\91-0.2340.hdf5
#
# Epoch 00092: val_loss improved from 0.23404 to 0.23259, saving model to ./model\92-0.2326.hdf5
#
# Epoch 00093: val_loss improved from 0.23259 to 0.23082, saving model to ./model\93-0.2308.hdf5
#
# Epoch 00094: val_loss improved from 0.23082 to 0.22900, saving model to ./model\94-0.2290.hdf5
#
# Epoch 00095: val_loss improved from 0.22900 to 0.22754, saving model to ./model\95-0.2275.hdf5
#
# Epoch 00096: val_loss improved from 0.22754 to 0.22683, saving model to ./model\96-0.2268.hdf5
#
# Epoch 00097: val_loss improved from 0.22683 to 0.22649, saving model to ./model\97-0.2265.hdf5
#
# Epoch 00098: val_loss improved from 0.22649 to 0.22600, saving model to ./model\98-0.2260.hdf5
#
# Epoch 00099: val_loss improved from 0.22600 to 0.22508, saving model to ./model\99-0.2251.hdf5
#
# Epoch 00100: val_loss improved from 0.22508 to 0.22336, saving model to ./model\100-0.2234.hdf5
#
# Epoch 00101: val_loss improved from 0.22336 to 0.22107, saving model to ./model\101-0.2211.hdf5
#
# Epoch 00102: val_loss improved from 0.22107 to 0.21922, saving model to ./model\102-0.2192.hdf5
#
# Epoch 00103: val_loss improved from 0.21922 to 0.21831, saving model to ./model\103-0.2183.hdf5
#
# Epoch 00104: val_loss improved from 0.21831 to 0.21795, saving model to ./model\104-0.2179.hdf5
#
# Epoch 00105: val_loss improved from 0.21795 to 0.21723, saving model to ./model\105-0.2172.hdf5
#
# Epoch 00106: val_loss improved from 0.21723 to 0.21595, saving model to ./model\106-0.2159.hdf5
#
# Epoch 00107: val_loss improved from 0.21595 to 0.21398, saving model to ./model\107-0.2140.hdf5
#
# Epoch 00108: val_loss improved from 0.21398 to 0.21223, saving model to ./model\108-0.2122.hdf5
#
# Epoch 00109: val_loss improved from 0.21223 to 0.21093, saving model to ./model\109-0.2109.hdf5
#
# Epoch 00110: val_loss improved from 0.21093 to 0.21003, saving model to ./model\110-0.2100.hdf5
#
# Epoch 00111: val_loss improved from 0.21003 to 0.20937, saving model to ./model\111-0.2094.hdf5
#
# Epoch 00112: val_loss improved from 0.20937 to 0.20832, saving model to ./model\112-0.2083.hdf5
#
# Epoch 00113: val_loss improved from 0.20832 to 0.20668, saving model to ./model\113-0.2067.hdf5
# Epoch 00114: val_loss improved from 0.20668 to 0.20488, saving model to ./model\114-0.2049.hdf5
#
# Epoch 00115: val_loss improved from 0.20488 to 0.20349, saving model to ./model\115-0.2035.hdf5
#
# Epoch 00116: val_loss improved from 0.20349 to 0.20245, saving model to ./model\116-0.2025.hdf5
#
# Epoch 00117: val_loss improved from 0.20245 to 0.20142, saving model to ./model\117-0.2014.hdf5
#
# Epoch 00118: val_loss improved from 0.20142 to 0.20041, saving model to ./model\118-0.2004.hdf5
#
# Epoch 00119: val_loss improved from 0.20041 to 0.19937, saving model to ./model\119-0.1994.hdf5
#
# Epoch 00120: val_loss improved from 0.19937 to 0.19850, saving model to ./model\120-0.1985.hdf5
#
# Epoch 00121: val_loss improved from 0.19850 to 0.19782, saving model to ./model\121-0.1978.hdf5
#
# Epoch 00122: val_loss improved from 0.19782 to 0.19697, saving model to ./model\122-0.1970.hdf5
#
# Epoch 00123: val_loss improved from 0.19697 to 0.19544, saving model to ./model\123-0.1954.hdf5
#
# Epoch 00124: val_loss improved from 0.19544 to 0.19362, saving model to ./model\124-0.1936.hdf5
#
# Epoch 00125: val_loss improved from 0.19362 to 0.19211, saving model to ./model\125-0.1921.hdf5
#
# Epoch 00126: val_loss improved from 0.19211 to 0.19189, saving model to ./model\126-0.1919.hdf5
#
# Epoch 00127: val_loss did not improve from 0.19189
#
# Epoch 00128: val_loss did not improve from 0.19189
#
# Epoch 00129: val_loss improved from 0.19189 to 0.19079, saving model to ./model\129-0.1908.hdf5
#
# Epoch 00130: val_loss improved from 0.19079 to 0.18914, saving model to ./model\130-0.1891.hdf5
#
# Epoch 00131: val_loss improved from 0.18914 to 0.18773, saving model to ./model\131-0.1877.hdf5
#
# Epoch 00132: val_loss improved from 0.18773 to 0.18701, saving model to ./model\132-0.1870.hdf5
#
# Epoch 00133: val_loss improved from 0.18701 to 0.18675, saving model to ./model\133-0.1868.hdf5
#
# Epoch 00134: val_loss did not improve from 0.18675
#
# Epoch 00135: val_loss improved from 0.18675 to 0.18617, saving model to ./model\135-0.1862.hdf5
#
# Epoch 00136: val_loss improved from 0.18617 to 0.18515, saving model to ./model\136-0.1851.hdf5
#
# Epoch 00137: val_loss improved from 0.18515 to 0.18501, saving model to ./model\137-0.1850.hdf5
#
# Epoch 00138: val_loss did not improve from 0.18501
#
# Epoch 00139: val_loss did not improve from 0.18501
#
# Epoch 00140: val_loss improved from 0.18501 to 0.18477, saving model to ./model\140-0.1848.hdf5
#
# Epoch 00141: val_loss improved from 0.18477 to 0.18309, saving model to ./model\141-0.1831.hdf5
#
# Epoch 00142: val_loss improved from 0.18309 to 0.18100, saving model to ./model\142-0.1810.hdf5
#
# Epoch 00143: val_loss improved from 0.18100 to 0.17922, saving model to ./model\143-0.1792.hdf5
#
# Epoch 00144: val_loss improved from 0.17922 to 0.17853, saving model to ./model\144-0.1785.hdf5
#
# Epoch 00145: val_loss improved from 0.17853 to 0.17826, saving model to ./model\145-0.1783.hdf5
#
# Epoch 00146: val_loss improved from 0.17826 to 0.17712, saving model to ./model\146-0.1771.hdf5
#
# Epoch 00147: val_loss improved from 0.17712 to 0.17558, saving model to ./model\147-0.1756.hdf5
#
# Epoch 00148: val_loss improved from 0.17558 to 0.17419, saving model to ./model\148-0.1742.hdf5
#
# Epoch 00149: val_loss improved from 0.17419 to 0.17344, saving model to ./model\149-0.1734.hdf5
#
# Epoch 00150: val_loss improved from 0.17344 to 0.17322, saving model to ./model\150-0.1732.hdf5
#
# Epoch 00151: val_loss improved from 0.17322 to 0.17264, saving model to ./model\151-0.1726.hdf5
#
# Epoch 00152: val_loss improved from 0.17264 to 0.17104, saving model to ./model\152-0.1710.hdf5
#
# Epoch 00153: val_loss improved from 0.17104 to 0.16923, saving model to ./model\153-0.1692.hdf5
#
# Epoch 00154: val_loss improved from 0.16923 to 0.16869, saving model to ./model\154-0.1687.hdf5
#
# Epoch 00155: val_loss did not improve from 0.16869
#
# Epoch 00156: val_loss improved from 0.16869 to 0.16821, saving model to ./model\156-0.1682.hdf5
#
# Epoch 00157: val_loss improved from 0.16821 to 0.16777, saving model to ./model\157-0.1678.hdf5
#
# Epoch 00158: val_loss improved from 0.16777 to 0.16725, saving model to ./model\158-0.1672.hdf5
#
# Epoch 00159: val_loss improved from 0.16725 to 0.16582, saving model to ./model\159-0.1658.hdf5
#
# Epoch 00160: val_loss improved from 0.16582 to 0.16445, saving model to ./model\160-0.1644.hdf5
#
# Epoch 00161: val_loss improved from 0.16445 to 0.16381, saving model to ./model\161-0.1638.hdf5
#
# Epoch 00162: val_loss did not improve from 0.16381
#
# Epoch 00163: val_loss did not improve from 0.16381
#
# Epoch 00164: val_loss improved from 0.16381 to 0.16345, saving model to ./model\164-0.1635.hdf5
#
# Epoch 00165: val_loss improved from 0.16345 to 0.16182, saving model to ./model\165-0.1618.hdf5
#
# Epoch 00166: val_loss improved from 0.16182 to 0.16087, saving model to ./model\166-0.1609.hdf5
#
# Epoch 00167: val_loss did not improve from 0.16087
#
# Epoch 00168: val_loss did not improve from 0.16087
#
# Epoch 00169: val_loss improved from 0.16087 to 0.16082, saving model to ./model\169-0.1608.hdf5
#
# Epoch 00170: val_loss improved from 0.16082 to 0.15989, saving model to ./model\170-0.1599.hdf5
#
# Epoch 00171: val_loss improved from 0.15989 to 0.15928, saving model to ./model\171-0.1593.hdf5
#
# Epoch 00172: val_loss improved from 0.15928 to 0.15845, saving model to ./model\172-0.1584.hdf5
#
# Epoch 00173: val_loss improved from 0.15845 to 0.15713, saving model to ./model\173-0.1571.hdf5
#
# Epoch 00174: val_loss improved from 0.15713 to 0.15670, saving model to ./model\174-0.1567.hdf5
#
# Epoch 00175: val_loss improved from 0.15670 to 0.15628, saving model to ./model\175-0.1563.hdf5
#
# Epoch 00176: val_loss improved from 0.15628 to 0.15539, saving model to ./model\176-0.1554.hdf5
#
# Epoch 00177: val_loss improved from 0.15539 to 0.15523, saving model to ./model\177-0.1552.hdf5
#
# Epoch 00178: val_loss improved from 0.15523 to 0.15499, saving model to ./model\178-0.1550.hdf5
#
# Epoch 00179: val_loss improved from 0.15499 to 0.15443, saving model to ./model\179-0.1544.hdf5
#
# Epoch 00180: val_loss improved from 0.15443 to 0.15290, saving model to ./model\180-0.1529.hdf5
#
# Epoch 00181: val_loss improved from 0.15290 to 0.15195, saving model to ./model\181-0.1519.hdf5
#
# Epoch 00182: val_loss improved from 0.15195 to 0.15176, saving model to ./model\182-0.1518.hdf5
#
# Epoch 00183: val_loss improved from 0.15176 to 0.15078, saving model to ./model\183-0.1508.hdf5
#
# Epoch 00184: val_loss improved from 0.15078 to 0.14929, saving model to ./model\184-0.1493.hdf5
#
# Epoch 00185: val_loss did not improve from 0.14929
#
# Epoch 00186: val_loss did not improve from 0.14929
#
# Epoch 00187: val_loss improved from 0.14929 to 0.14881, saving model to ./model\187-0.1488.hdf5
#
# Epoch 00188: val_loss improved from 0.14881 to 0.14672, saving model to ./model\188-0.1467.hdf5
#
# Epoch 00189: val_loss did not improve from 0.14672
#
# Epoch 00190: val_loss did not improve from 0.14672
#
# Epoch 00191: val_loss improved from 0.14672 to 0.14625, saving model to ./model\191-0.1463.hdf5
#
# Epoch 00192: val_loss improved from 0.14625 to 0.14483, saving model to ./model\192-0.1448.hdf5
#
# Epoch 00193: val_loss improved from 0.14483 to 0.14430, saving model to ./model\193-0.1443.hdf5
#
# Epoch 00194: val_loss improved from 0.14430 to 0.14422, saving model to ./model\194-0.1442.hdf5
#
# Epoch 00195: val_loss improved from 0.14422 to 0.14371, saving model to ./model\195-0.1437.hdf5
#
# Epoch 00196: val_loss improved from 0.14371 to 0.14357, saving model to ./model\196-0.1436.hdf5
#
# Epoch 00197: val_loss improved from 0.14357 to 0.14173, saving model to ./model\197-0.1417.hdf5
#
# Epoch 00198: val_loss improved from 0.14173 to 0.13974, saving model to ./model\198-0.1397.hdf5
#
# Epoch 00199: val_loss did not improve from 0.13974
#
# Epoch 00200: val_loss did not improve from 0.13974
#
# Epoch 00201: val_loss did not improve from 0.13974
#
# Epoch 00202: val_loss improved from 0.13974 to 0.13895, saving model to ./model\202-0.1389.hdf5
#
# Epoch 00203: val_loss did not improve from 0.13895
#
# Epoch 00204: val_loss did not improve from 0.13895
#
# Epoch 00205: val_loss improved from 0.13895 to 0.13830, saving model to ./model\205-0.1383.hdf5
#
# Epoch 00206: val_loss improved from 0.13830 to 0.13708, saving model to ./model\206-0.1371.hdf5
#
# Epoch 00207: val_loss improved from 0.13708 to 0.13671, saving model to ./model\207-0.1367.hdf5
# Epoch 00208: val_loss did not improve from 0.13671
#
# Epoch 00209: val_loss did not improve from 0.13671
#
# Epoch 00210: val_loss did not improve from 0.13671
#
# Epoch 00211: val_loss improved from 0.13671 to 0.13656, saving model to ./model\211-0.1366.hdf5
#
# Epoch 00212: val_loss improved from 0.13656 to 0.13441, saving model to ./model\212-0.1344.hdf5
#
# Epoch 00213: val_loss did not improve from 0.13441
#
# Epoch 00214: val_loss did not improve from 0.13441
#
# Epoch 00215: val_loss did not improve from 0.13441
#
# Epoch 00216: val_loss did not improve from 0.13441
#
# Epoch 00217: val_loss did not improve from 0.13441
#
# Epoch 00218: val_loss did not improve from 0.13441
#
# Epoch 00219: val_loss did not improve from 0.13441
#
# Epoch 00220: val_loss improved from 0.13441 to 0.13167, saving model to ./model\220-0.1317.hdf5
#
# Epoch 00221: val_loss improved from 0.13167 to 0.13089, saving model to ./model\221-0.1309.hdf5
#
# Epoch 00222: val_loss did not improve from 0.13089
#
# Epoch 00223: val_loss did not improve from 0.13089
#
# Epoch 00224: val_loss did not improve from 0.13089
#
# Epoch 00225: val_loss did not improve from 0.13089
#
# Epoch 00226: val_loss did not improve from 0.13089
#
# Epoch 00227: val_loss did not improve from 0.13089
#
# Epoch 00228: val_loss did not improve from 0.13089
#
# Epoch 00229: val_loss did not improve from 0.13089
#
# Epoch 00230: val_loss improved from 0.13089 to 0.12966, saving model to ./model\230-0.1297.hdf5
#
# Epoch 00231: val_loss improved from 0.12966 to 0.12921, saving model to ./model\231-0.1292.hdf5
#
# Epoch 00232: val_loss did not improve from 0.12921
#
# Epoch 00233: val_loss did not improve from 0.12921
#
# Epoch 00234: val_loss improved from 0.12921 to 0.12715, saving model to ./model\234-0.1271.hdf5
#
# Epoch 00235: val_loss improved from 0.12715 to 0.12535, saving model to ./model\235-0.1254.hdf5
#
# Epoch 00236: val_loss did not improve from 0.12535
#
# Epoch 00237: val_loss did not improve from 0.12535
#
# Epoch 00238: val_loss did not improve from 0.12535
#
# Epoch 00239: val_loss did not improve from 0.12535
#
# Epoch 00240: val_loss improved from 0.12535 to 0.12473, saving model to ./model\240-0.1247.hdf5
#
# Epoch 00241: val_loss did not improve from 0.12473
#
# Epoch 00242: val_loss did not improve from 0.12473
#
# Epoch 00243: val_loss did not improve from 0.12473
#
# Epoch 00244: val_loss improved from 0.12473 to 0.12286, saving model to ./model\244-0.1229.hdf5
#
# Epoch 00245: val_loss did not improve from 0.12286
#
# Epoch 00246: val_loss did not improve from 0.12286
#
# Epoch 00247: val_loss did not improve from 0.12286
#
# Epoch 00248: val_loss improved from 0.12286 to 0.12236, saving model to ./model\248-0.1224.hdf5
#
# Epoch 00249: val_loss did not improve from 0.12236
#
# Epoch 00250: val_loss did not improve from 0.12236
#
# Epoch 00251: val_loss did not improve from 0.12236
#
# Epoch 00252: val_loss did not improve from 0.12236
#
# Epoch 00253: val_loss did not improve from 0.12236
#
# Epoch 00254: val_loss did not improve from 0.12236
#
# Epoch 00255: val_loss did not improve from 0.12236
#
# Epoch 00256: val_loss did not improve from 0.12236
#
# Epoch 00257: val_loss did not improve from 0.12236
#
# Epoch 00258: val_loss did not improve from 0.12236
#
# Epoch 00259: val_loss did not improve from 0.12236
#
# Epoch 00260: val_loss did not improve from 0.12236
#
# Epoch 00261: val_loss did not improve from 0.12236
#
# Epoch 00262: val_loss did not improve from 0.12236
#
# Epoch 00263: val_loss did not improve from 0.12236
#
# Epoch 00264: val_loss did not improve from 0.12236
#
# Epoch 00265: val_loss did not improve from 0.12236
#
# Epoch 00266: val_loss did not improve from 0.12236
#
# Epoch 00267: val_loss did not improve from 0.12236
#
# Epoch 00268: val_loss improved from 0.12236 to 0.12224, saving model to ./model\268-0.1222.hdf5
#
# Epoch 00269: val_loss did not improve from 0.12224
#
# Epoch 00270: val_loss did not improve from 0.12224
#
# Epoch 00271: val_loss did not improve from 0.12224
#
# Epoch 00272: val_loss did not improve from 0.12224
#
# Epoch 00273: val_loss did not improve from 0.12224
#
# Epoch 00274: val_loss did not improve from 0.12224
#
# Epoch 00275: val_loss did not improve from 0.12224
#
# Epoch 00276: val_loss did not improve from 0.12224
#
# Epoch 00277: val_loss did not improve from 0.12224
#
# Epoch 00278: val_loss did not improve from 0.12224
#
# Epoch 00279: val_loss did not improve from 0.12224
#
# Epoch 00280: val_loss did not improve from 0.12224
#
# Epoch 00281: val_loss did not improve from 0.12224
#
# Epoch 00282: val_loss did not improve from 0.12224
#
# Epoch 00283: val_loss improved from 0.12224 to 0.12124, saving model to ./model\283-0.1212.hdf5
#
# Epoch 00284: val_loss improved from 0.12124 to 0.12030, saving model to ./model\284-0.1203.hdf5
#
# Epoch 00285: val_loss did not improve from 0.12030
#
# Epoch 00286: val_loss did not improve from 0.12030
#
# Epoch 00287: val_loss did not improve from 0.12030
#
# Epoch 00288: val_loss did not improve from 0.12030
#
# Epoch 00289: val_loss improved from 0.12030 to 0.12030, saving model to ./model\289-0.1203.hdf5
#
# Epoch 00290: val_loss did not improve from 0.12030
#
# Epoch 00291: val_loss did not improve from 0.12030
#
# Epoch 00292: val_loss did not improve from 0.12030
#
# Epoch 00293: val_loss did not improve from 0.12030
#
# Epoch 00294: val_loss did not improve from 0.12030
#
# Epoch 00295: val_loss improved from 0.12030 to 0.12008, saving model to ./model\295-0.1201.hdf5
#
# Epoch 00296: val_loss did not improve from 0.12008
#
# Epoch 00297: val_loss did not improve from 0.12008
#
# Epoch 00298: val_loss improved from 0.12008 to 0.11992, saving model to ./model\298-0.1199.hdf5
#
# Epoch 00299: val_loss improved from 0.11992 to 0.11889, saving model to ./model\299-0.1189.hdf5
#
# Epoch 00300: val_loss did not improve from 0.11889
#
# Epoch 00301: val_loss did not improve from 0.11889
#
# Epoch 00302: val_loss improved from 0.11889 to 0.11865, saving model to ./model\302-0.1186.hdf5
#
# Epoch 00303: val_loss improved from 0.11865 to 0.11752, saving model to ./model\303-0.1175.hdf5
#
# Epoch 00304: val_loss did not improve from 0.11752
#
# Epoch 00305: val_loss did not improve from 0.11752
#
# Epoch 00306: val_loss improved from 0.11752 to 0.11607, saving model to ./model\306-0.1161.hdf5
#
# Epoch 00307: val_loss did not improve from 0.11607
#
# Epoch 00308: val_loss did not improve from 0.11607
#
# Epoch 00309: val_loss did not improve from 0.11607
#
# Epoch 00310: val_loss improved from 0.11607 to 0.11594, saving model to ./model\310-0.1159.hdf5
#
# Epoch 00311: val_loss improved from 0.11594 to 0.11584, saving model to ./model\311-0.1158.hdf5
#
# Epoch 00312: val_loss did not improve from 0.11584
#
# Epoch 00313: val_loss improved from 0.11584 to 0.11552, saving model to ./model\313-0.1155.hdf5
#
# Epoch 00314: val_loss did not improve from 0.11552
#
# Epoch 00315: val_loss did not improve from 0.11552
#
# Epoch 00316: val_loss improved from 0.11552 to 0.11522, saving model to ./model\316-0.1152.hdf5
#
# Epoch 00317: val_loss improved from 0.11522 to 0.11508, saving model to ./model\317-0.1151.hdf5
#
# Epoch 00318: val_loss did not improve from 0.11508
#
# Epoch 00319: val_loss did not improve from 0.11508
#
# Epoch 00320: val_loss improved from 0.11508 to 0.11418, saving model to ./model\320-0.1142.hdf5
#
# Epoch 00321: val_loss improved from 0.11418 to 0.11283, saving model to ./model\321-0.1128.hdf5
#
# Epoch 00322: val_loss did not improve from 0.11283
#
# Epoch 00323: val_loss did not improve from 0.11283
#
# Epoch 00324: val_loss did not improve from 0.11283
#
# Epoch 00325: val_loss did not improve from 0.11283
#
# Epoch 00326: val_loss improved from 0.11283 to 0.11221, saving model to ./model\326-0.1122.hdf5
#
# Epoch 00327: val_loss improved from 0.11221 to 0.11171, saving model to ./model\327-0.1117.hdf5
#
# Epoch 00328: val_loss improved from 0.11171 to 0.11052, saving model to ./model\328-0.1105.hdf5
#
# Epoch 00329: val_loss improved from 0.11052 to 0.10985, saving model to ./model\329-0.1098.hdf5
#
# Epoch 00330: val_loss did not improve from 0.10985
#
# Epoch 00331: val_loss improved from 0.10985 to 0.10984, saving model to ./model\331-0.1098.hdf5
#
# Epoch 00332: val_loss improved from 0.10984 to 0.10853, saving model to ./model\332-0.1085.hdf5
#
# Epoch 00333: val_loss did not improve from 0.10853
#
# Epoch 00334: val_loss did not improve from 0.10853
#
# Epoch 00335: val_loss improved from 0.10853 to 0.10801, saving model to ./model\335-0.1080.hdf5
#
# Epoch 00336: val_loss did not improve from 0.10801
#
# Epoch 00337: val_loss did not improve from 0.10801
#
# Epoch 00338: val_loss did not improve from 0.10801
# Epoch 00339: val_loss improved from 0.10801 to 0.10706, saving model to ./model\339-0.1071.hdf5
#
# Epoch 00340: val_loss did not improve from 0.10706
#
# Epoch 00341: val_loss did not improve from 0.10706
#
# Epoch 00342: val_loss improved from 0.10706 to 0.10642, saving model to ./model\342-0.1064.hdf5
#
# Epoch 00343: val_loss improved from 0.10642 to 0.10522, saving model to ./model\343-0.1052.hdf5
#
# Epoch 00344: val_loss did not improve from 0.10522
#
# Epoch 00345: val_loss did not improve from 0.10522
#
# Epoch 00346: val_loss improved from 0.10522 to 0.10439, saving model to ./model\346-0.1044.hdf5
#
# Epoch 00347: val_loss improved from 0.10439 to 0.10383, saving model to ./model\347-0.1038.hdf5
#
# Epoch 00348: val_loss did not improve from 0.10383
#
# Epoch 00349: val_loss did not improve from 0.10383
#
# Epoch 00350: val_loss improved from 0.10383 to 0.10281, saving model to ./model\350-0.1028.hdf5
#
# Epoch 00351: val_loss improved from 0.10281 to 0.10186, saving model to ./model\351-0.1019.hdf5
#
# Epoch 00352: val_loss did not improve from 0.10186
#
# Epoch 00353: val_loss did not improve from 0.10186
#
# Epoch 00354: val_loss improved from 0.10186 to 0.09990, saving model to ./model\354-0.0999.hdf5
#
# Epoch 00355: val_loss did not improve from 0.09990
#
# Epoch 00356: val_loss did not improve from 0.09990
#
# Epoch 00357: val_loss did not improve from 0.09990
#
# Epoch 00358: val_loss did not improve from 0.09990
#
# Epoch 00359: val_loss did not improve from 0.09990
#
# Epoch 00360: val_loss did not improve from 0.09990
#
# Epoch 00361: val_loss improved from 0.09990 to 0.09960, saving model to ./model\361-0.0996.hdf5
#
# Epoch 00362: val_loss did not improve from 0.09960
#
# Epoch 00363: val_loss improved from 0.09960 to 0.09943, saving model to ./model\363-0.0994.hdf5
#
# Epoch 00364: val_loss improved from 0.09943 to 0.09802, saving model to ./model\364-0.0980.hdf5
#
# Epoch 00365: val_loss improved from 0.09802 to 0.09776, saving model to ./model\365-0.0978.hdf5
#
# Epoch 00366: val_loss did not improve from 0.09776
#
# Epoch 00367: val_loss did not improve from 0.09776
#
# Epoch 00368: val_loss improved from 0.09776 to 0.09675, saving model to ./model\368-0.0967.hdf5
#
# Epoch 00369: val_loss improved from 0.09675 to 0.09576, saving model to ./model\369-0.0958.hdf5
#
# Epoch 00370: val_loss did not improve from 0.09576
#
# Epoch 00371: val_loss did not improve from 0.09576
#
# Epoch 00372: val_loss improved from 0.09576 to 0.09383, saving model to ./model\372-0.0938.hdf5
#
# Epoch 00373: val_loss did not improve from 0.09383
#
# Epoch 00374: val_loss did not improve from 0.09383
#
# Epoch 00375: val_loss did not improve from 0.09383
#
# Epoch 00376: val_loss did not improve from 0.09383
#
# Epoch 00377: val_loss did not improve from 0.09383
#
# Epoch 00378: val_loss did not improve from 0.09383
#
# Epoch 00379: val_loss improved from 0.09383 to 0.09295, saving model to ./model\379-0.0929.hdf5
#
# Epoch 00380: val_loss improved from 0.09295 to 0.09237, saving model to ./model\380-0.0924.hdf5
#
# Epoch 00381: val_loss did not improve from 0.09237
#
# Epoch 00382: val_loss did not improve from 0.09237
#
# Epoch 00383: val_loss improved from 0.09237 to 0.09193, saving model to ./model\383-0.0919.hdf5
#
# Epoch 00384: val_loss improved from 0.09193 to 0.09180, saving model to ./model\384-0.0918.hdf5
#
# Epoch 00385: val_loss did not improve from 0.09180
#
# Epoch 00386: val_loss did not improve from 0.09180
#
# Epoch 00387: val_loss improved from 0.09180 to 0.09128, saving model to ./model\387-0.0913.hdf5
#
# Epoch 00388: val_loss did not improve from 0.09128
#
# Epoch 00389: val_loss improved from 0.09128 to 0.09095, saving model to ./model\389-0.0910.hdf5
#
# Epoch 00390: val_loss improved from 0.09095 to 0.08997, saving model to ./model\390-0.0900.hdf5
#
# Epoch 00391: val_loss did not improve from 0.08997
#
# Epoch 00392: val_loss did not improve from 0.08997
#
# Epoch 00393: val_loss improved from 0.08997 to 0.08955, saving model to ./model\393-0.0895.hdf5
#
# Epoch 00394: val_loss improved from 0.08955 to 0.08877, saving model to ./model\394-0.0888.hdf5
#
# Epoch 00395: val_loss did not improve from 0.08877
#
# Epoch 00396: val_loss improved from 0.08877 to 0.08851, saving model to ./model\396-0.0885.hdf5
#
# Epoch 00397: val_loss improved from 0.08851 to 0.08727, saving model to ./model\397-0.0873.hdf5
#
# Epoch 00398: val_loss did not improve from 0.08727
#
# Epoch 00399: val_loss did not improve from 0.08727
#
# Epoch 00400: val_loss improved from 0.08727 to 0.08658, saving model to ./model\400-0.0866.hdf5
#
# Epoch 00401: val_loss improved from 0.08658 to 0.08647, saving model to ./model\401-0.0865.hdf5
#
# Epoch 00402: val_loss did not improve from 0.08647
#
# Epoch 00403: val_loss improved from 0.08647 to 0.08618, saving model to ./model\403-0.0862.hdf5
#
# Epoch 00404: val_loss improved from 0.08618 to 0.08594, saving model to ./model\404-0.0859.hdf5
#
# Epoch 00405: val_loss did not improve from 0.08594
#
# Epoch 00406: val_loss did not improve from 0.08594
#
# Epoch 00407: val_loss improved from 0.08594 to 0.08505, saving model to ./model\407-0.0851.hdf5
#
# Epoch 00408: val_loss improved from 0.08505 to 0.08458, saving model to ./model\408-0.0846.hdf5
#
# Epoch 00409: val_loss did not improve from 0.08458
#
# Epoch 00410: val_loss did not improve from 0.08458
#
# Epoch 00411: val_loss did not improve from 0.08458
#
# Epoch 00412: val_loss did not improve from 0.08458
#
# Epoch 00413: val_loss did not improve from 0.08458
#
# Epoch 00414: val_loss did not improve from 0.08458
#
# Epoch 00415: val_loss improved from 0.08458 to 0.08388, saving model to ./model\415-0.0839.hdf5
#
# Epoch 00416: val_loss did not improve from 0.08388
#
# Epoch 00417: val_loss did not improve from 0.08388
#
# Epoch 00418: val_loss did not improve from 0.08388
#
# Epoch 00419: val_loss improved from 0.08388 to 0.08330, saving model to ./model\419-0.0833.hdf5
#
# Epoch 00420: val_loss did not improve from 0.08330
#
# Epoch 00421: val_loss did not improve from 0.08330
#
# Epoch 00422: val_loss improved from 0.08330 to 0.08153, saving model to ./model\422-0.0815.hdf5
#
# Epoch 00423: val_loss did not improve from 0.08153
#
# Epoch 00424: val_loss did not improve from 0.08153
#
# Epoch 00425: val_loss improved from 0.08153 to 0.08105, saving model to ./model\425-0.0811.hdf5
#
# Epoch 00426: val_loss improved from 0.08105 to 0.08081, saving model to ./model\426-0.0808.hdf5
#
# Epoch 00427: val_loss did not improve from 0.08081
#
# Epoch 00428: val_loss did not improve from 0.08081
#
# Epoch 00429: val_loss did not improve from 0.08081
#
# Epoch 00430: val_loss did not improve from 0.08081
#
# Epoch 00431: val_loss improved from 0.08081 to 0.08001, saving model to ./model\431-0.0800.hdf5
#
# Epoch 00432: val_loss improved from 0.08001 to 0.07962, saving model to ./model\432-0.0796.hdf5
#
# Epoch 00433: val_loss did not improve from 0.07962
#
# Epoch 00434: val_loss did not improve from 0.07962
#
# Epoch 00435: val_loss did not improve from 0.07962
#
# Epoch 00436: val_loss did not improve from 0.07962
#
# Epoch 00437: val_loss did not improve from 0.07962
#
# Epoch 00438: val_loss did not improve from 0.07962
#
# Epoch 00439: val_loss did not improve from 0.07962
#
# Epoch 00440: val_loss improved from 0.07962 to 0.07892, saving model to ./model\440-0.0789.hdf5
#
# Epoch 00441: val_loss improved from 0.07892 to 0.07886, saving model to ./model\441-0.0789.hdf5
#
# Epoch 00442: val_loss did not improve from 0.07886
#
# Epoch 00443: val_loss improved from 0.07886 to 0.07822, saving model to ./model\443-0.0782.hdf5
#
# Epoch 00444: val_loss improved from 0.07822 to 0.07750, saving model to ./model\444-0.0775.hdf5
#
# Epoch 00445: val_loss did not improve from 0.07750
#
# Epoch 00446: val_loss improved from 0.07750 to 0.07696, saving model to ./model\446-0.0770.hdf5
#
# Epoch 00447: val_loss improved from 0.07696 to 0.07587, saving model to ./model\447-0.0759.hdf5
#
# Epoch 00448: val_loss did not improve from 0.07587
#
# Epoch 00449: val_loss improved from 0.07587 to 0.07574, saving model to ./model\449-0.0757.hdf5
#
# Epoch 00450: val_loss improved from 0.07574 to 0.07535, saving model to ./model\450-0.0754.hdf5
#
# Epoch 00451: val_loss did not improve from 0.07535
#
# Epoch 00452: val_loss did not improve from 0.07535
#
# Epoch 00453: val_loss did not improve from 0.07535
#
# Epoch 00454: val_loss improved from 0.07535 to 0.07458, saving model to ./model\454-0.0746.hdf5
#
# Epoch 00455: val_loss did not improve from 0.07458
#
# Epoch 00456: val_loss did not improve from 0.07458
#
# Epoch 00457: val_loss did not improve from 0.07458
#
# Epoch 00458: val_loss did not improve from 0.07458
#
# Epoch 00459: val_loss did not improve from 0.07458
#
# Epoch 00460: val_loss did not improve from 0.07458
# Epoch 00461: val_loss improved from 0.07458 to 0.07454, saving model to ./model\461-0.0745.hdf5
#
# Epoch 00462: val_loss did not improve from 0.07454
#
# Epoch 00463: val_loss did not improve from 0.07454
#
# Epoch 00464: val_loss did not improve from 0.07454
#
# Epoch 00465: val_loss improved from 0.07454 to 0.07402, saving model to ./model\465-0.0740.hdf5
#
# Epoch 00466: val_loss did not improve from 0.07402
#
# Epoch 00467: val_loss did not improve from 0.07402
#
# Epoch 00468: val_loss improved from 0.07402 to 0.07344, saving model to ./model\468-0.0734.hdf5
#
# Epoch 00469: val_loss did not improve from 0.07344
#
# Epoch 00470: val_loss did not improve from 0.07344
#
# Epoch 00471: val_loss did not improve from 0.07344
#
# Epoch 00472: val_loss improved from 0.07344 to 0.07296, saving model to ./model\472-0.0730.hdf5
#
# Epoch 00473: val_loss did not improve from 0.07296
#
# Epoch 00474: val_loss did not improve from 0.07296
#
# Epoch 00475: val_loss did not improve from 0.07296
#
# Epoch 00476: val_loss did not improve from 0.07296
#
# Epoch 00477: val_loss did not improve from 0.07296
#
# Epoch 00478: val_loss did not improve from 0.07296
#
# Epoch 00479: val_loss did not improve from 0.07296
#
# Epoch 00480: val_loss improved from 0.07296 to 0.07266, saving model to ./model\480-0.0727.hdf5
#
# Epoch 00481: val_loss did not improve from 0.07266
#
# Epoch 00482: val_loss did not improve from 0.07266
#
# Epoch 00483: val_loss improved from 0.07266 to 0.07205, saving model to ./model\483-0.0721.hdf5
#
# Epoch 00484: val_loss improved from 0.07205 to 0.07187, saving model to ./model\484-0.0719.hdf5
#
# Epoch 00485: val_loss did not improve from 0.07187
#
# Epoch 00486: val_loss did not improve from 0.07187
#
# Epoch 00487: val_loss improved from 0.07187 to 0.07076, saving model to ./model\487-0.0708.hdf5
#
# Epoch 00488: val_loss did not improve from 0.07076
#
# Epoch 00489: val_loss did not improve from 0.07076
#
# Epoch 00490: val_loss did not improve from 0.07076
#
# Epoch 00491: val_loss did not improve from 0.07076
#
# Epoch 00492: val_loss did not improve from 0.07076
#
# Epoch 00493: val_loss did not improve from 0.07076
#
# Epoch 00494: val_loss did not improve from 0.07076
#
# Epoch 00495: val_loss did not improve from 0.07076
#
# Epoch 00496: val_loss did not improve from 0.07076
#
# Epoch 00497: val_loss did not improve from 0.07076
#
# Epoch 00498: val_loss did not improve from 0.07076
#
# Epoch 00499: val_loss did not improve from 0.07076
#
# Epoch 00500: val_loss improved from 0.07076 to 0.07042, saving model to ./model\500-0.0704.hdf5
#
# Epoch 00501: val_loss improved from 0.07042 to 0.06978, saving model to ./model\501-0.0698.hdf5
#
# Epoch 00502: val_loss did not improve from 0.06978
#
# Epoch 00503: val_loss did not improve from 0.06978
#
# Epoch 00504: val_loss improved from 0.06978 to 0.06965, saving model to ./model\504-0.0697.hdf5
#
# Epoch 00505: val_loss did not improve from 0.06965
#
# Epoch 00506: val_loss did not improve from 0.06965
#
# Epoch 00507: val_loss did not improve from 0.06965
#
# Epoch 00508: val_loss did not improve from 0.06965
#
# Epoch 00509: val_loss did not improve from 0.06965
#
# Epoch 00510: val_loss improved from 0.06965 to 0.06958, saving model to ./model\510-0.0696.hdf5
#
# Epoch 00511: val_loss did not improve from 0.06958
#
# Epoch 00512: val_loss did not improve from 0.06958
#
# Epoch 00513: val_loss did not improve from 0.06958
#
# Epoch 00514: val_loss did not improve from 0.06958
#
# Epoch 00515: val_loss did not improve from 0.06958
#
# Epoch 00516: val_loss did not improve from 0.06958
#
# Epoch 00517: val_loss did not improve from 0.06958
#
# Epoch 00518: val_loss did not improve from 0.06958
#
# Epoch 00519: val_loss did not improve from 0.06958
#
# Epoch 00520: val_loss did not improve from 0.06958
#
# Epoch 00521: val_loss improved from 0.06958 to 0.06952, saving model to ./model\521-0.0695.hdf5
#
# Epoch 00522: val_loss improved from 0.06952 to 0.06945, saving model to ./model\522-0.0695.hdf5
#
# Epoch 00523: val_loss did not improve from 0.06945
#
# Epoch 00524: val_loss did not improve from 0.06945
#
# Epoch 00525: val_loss did not improve from 0.06945
#
# Epoch 00526: val_loss did not improve from 0.06945
#
# Epoch 00527: val_loss did not improve from 0.06945
#
# Epoch 00528: val_loss did not improve from 0.06945
#
# Epoch 00529: val_loss did not improve from 0.06945
#
# Epoch 00530: val_loss did not improve from 0.06945
#
# Epoch 00531: val_loss did not improve from 0.06945
#
# Epoch 00532: val_loss did not improve from 0.06945
#
# Epoch 00533: val_loss did not improve from 0.06945
#
# Epoch 00534: val_loss did not improve from 0.06945
#
# Epoch 00535: val_loss did not improve from 0.06945
#
# Epoch 00536: val_loss did not improve from 0.06945
#
# Epoch 00537: val_loss did not improve from 0.06945
#
# Epoch 00538: val_loss did not improve from 0.06945
#
# Epoch 00539: val_loss did not improve from 0.06945
#
# Epoch 00540: val_loss did not improve from 0.06945
#
# Epoch 00541: val_loss did not improve from 0.06945
#
# Epoch 00542: val_loss did not improve from 0.06945
#
# Epoch 00543: val_loss did not improve from 0.06945
#
# Epoch 00544: val_loss did not improve from 0.06945
#
# Epoch 00545: val_loss did not improve from 0.06945
#
# Epoch 00546: val_loss did not improve from 0.06945
#
# Epoch 00547: val_loss did not improve from 0.06945
#
# Epoch 00548: val_loss did not improve from 0.06945
#
# Epoch 00549: val_loss did not improve from 0.06945
#
# Epoch 00550: val_loss did not improve from 0.06945
#
# Epoch 00551: val_loss did not improve from 0.06945
#
# Epoch 00552: val_loss did not improve from 0.06945
#
# Epoch 00553: val_loss did not improve from 0.06945
#
# Epoch 00554: val_loss did not improve from 0.06945
#
# Epoch 00555: val_loss did not improve from 0.06945
#
# Epoch 00556: val_loss did not improve from 0.06945
#
# Epoch 00557: val_loss did not improve from 0.06945
#
# Epoch 00558: val_loss did not improve from 0.06945
#
# Epoch 00559: val_loss did not improve from 0.06945
#
# Epoch 00560: val_loss did not improve from 0.06945
#
# Epoch 00561: val_loss did not improve from 0.06945
#
# Epoch 00562: val_loss did not improve from 0.06945
#
# Epoch 00563: val_loss did not improve from 0.06945
#
# Epoch 00564: val_loss did not improve from 0.06945
#
# Epoch 00565: val_loss did not improve from 0.06945
#
# Epoch 00566: val_loss did not improve from 0.06945
#
# Epoch 00567: val_loss did not improve from 0.06945
#
# Epoch 00568: val_loss did not improve from 0.06945
#
# Epoch 00569: val_loss did not improve from 0.06945
#
# Epoch 00570: val_loss did not improve from 0.06945
#
# Epoch 00571: val_loss did not improve from 0.06945
#
# Epoch 00572: val_loss did not improve from 0.06945
#
# Epoch 00573: val_loss did not improve from 0.06945
#
# Epoch 00574: val_loss did not improve from 0.06945
#
# Epoch 00575: val_loss did not improve from 0.06945
#
# Epoch 00576: val_loss did not improve from 0.06945
#
# Epoch 00577: val_loss did not improve from 0.06945
#
# Epoch 00578: val_loss did not improve from 0.06945
#
# Epoch 00579: val_loss did not improve from 0.06945
#
# Epoch 00580: val_loss did not improve from 0.06945
#
# Epoch 00581: val_loss did not improve from 0.06945
#
# Epoch 00582: val_loss did not improve from 0.06945
#
# Epoch 00583: val_loss did not improve from 0.06945
#
# Epoch 00584: val_loss did not improve from 0.06945
#
# Epoch 00585: val_loss did not improve from 0.06945
#
# Epoch 00586: val_loss did not improve from 0.06945
#
# Epoch 00587: val_loss did not improve from 0.06945
#
# Epoch 00588: val_loss did not improve from 0.06945
#
# Epoch 00589: val_loss did not improve from 0.06945
#
# Epoch 00590: val_loss did not improve from 0.06945
#
# Epoch 00591: val_loss did not improve from 0.06945
#
# Epoch 00592: val_loss did not improve from 0.06945
#
# Epoch 00593: val_loss did not improve from 0.06945
#
# Epoch 00594: val_loss did not improve from 0.06945
#
# Epoch 00595: val_loss did not improve from 0.06945
#
# Epoch 00596: val_loss did not improve from 0.06945
#
# Epoch 00597: val_loss did not improve from 0.06945
#
# Epoch 00598: val_loss did not improve from 0.06945
#
# Epoch 00599: val_loss did not improve from 0.06945
#
# Epoch 00600: val_loss did not improve from 0.06945
#
# Epoch 00601: val_loss did not improve from 0.06945
#
# Epoch 00602: val_loss did not improve from 0.06945
#
# Epoch 00603: val_loss did not improve from 0.06945
#
# Epoch 00604: val_loss did not improve from 0.06945
#
# Epoch 00605: val_loss did not improve from 0.06945
#
# Epoch 00606: val_loss did not improve from 0.06945
#
# Epoch 00607: val_loss did not improve from 0.06945
#
# Epoch 00608: val_loss did not improve from 0.06945
# Epoch 00609: val_loss did not improve from 0.06945
#
# Epoch 00610: val_loss did not improve from 0.06945
#
# Epoch 00611: val_loss did not improve from 0.06945
#
# Epoch 00612: val_loss improved from 0.06945 to 0.06866, saving model to ./model\612-0.0687.hdf5
#
# Epoch 00613: val_loss improved from 0.06866 to 0.06848, saving model to ./model\613-0.0685.hdf5
#
# Epoch 00614: val_loss did not improve from 0.06848
#
# Epoch 00615: val_loss did not improve from 0.06848
#
# Epoch 00616: val_loss improved from 0.06848 to 0.06817, saving model to ./model\616-0.0682.hdf5
#
# Epoch 00617: val_loss improved from 0.06817 to 0.06793, saving model to ./model\617-0.0679.hdf5
#
# Epoch 00618: val_loss did not improve from 0.06793
#
# Epoch 00619: val_loss did not improve from 0.06793
#
# Epoch 00620: val_loss improved from 0.06793 to 0.06789, saving model to ./model\620-0.0679.hdf5
#
# Epoch 00621: val_loss improved from 0.06789 to 0.06766, saving model to ./model\621-0.0677.hdf5
#
# Epoch 00622: val_loss did not improve from 0.06766
#
# Epoch 00623: val_loss did not improve from 0.06766
#
# Epoch 00624: val_loss did not improve from 0.06766
#
# Epoch 00625: val_loss did not improve from 0.06766
#
# Epoch 00626: val_loss did not improve from 0.06766
#
# Epoch 00627: val_loss improved from 0.06766 to 0.06761, saving model to ./model\627-0.0676.hdf5
#
# Epoch 00628: val_loss improved from 0.06761 to 0.06735, saving model to ./model\628-0.0673.hdf5
#
# Epoch 00629: val_loss did not improve from 0.06735
#
# Epoch 00630: val_loss did not improve from 0.06735
#
# Epoch 00631: val_loss improved from 0.06735 to 0.06721, saving model to ./model\631-0.0672.hdf5
#
# Epoch 00632: val_loss improved from 0.06721 to 0.06671, saving model to ./model\632-0.0667.hdf5
#
# Epoch 00633: val_loss did not improve from 0.06671
#
# Epoch 00634: val_loss did not improve from 0.06671
#
# Epoch 00635: val_loss did not improve from 0.06671
#
# Epoch 00636: val_loss did not improve from 0.06671
#
# Epoch 00637: val_loss improved from 0.06671 to 0.06624, saving model to ./model\637-0.0662.hdf5
#
# Epoch 00638: val_loss did not improve from 0.06624
#
# Epoch 00639: val_loss did not improve from 0.06624
#
# Epoch 00640: val_loss did not improve from 0.06624
#
# Epoch 00641: val_loss improved from 0.06624 to 0.06597, saving model to ./model\641-0.0660.hdf5
#
# Epoch 00642: val_loss did not improve from 0.06597
#
# Epoch 00643: val_loss did not improve from 0.06597
#
# Epoch 00644: val_loss did not improve from 0.06597
#
# Epoch 00645: val_loss did not improve from 0.06597
#
# Epoch 00646: val_loss did not improve from 0.06597
#
# Epoch 00647: val_loss improved from 0.06597 to 0.06597, saving model to ./model\647-0.0660.hdf5
#
# Epoch 00648: val_loss improved from 0.06597 to 0.06589, saving model to ./model\648-0.0659.hdf5
#
# Epoch 00649: val_loss did not improve from 0.06589
#
# Epoch 00650: val_loss did not improve from 0.06589
#
# Epoch 00651: val_loss improved from 0.06589 to 0.06550, saving model to ./model\651-0.0655.hdf5
#
# Epoch 00652: val_loss improved from 0.06550 to 0.06514, saving model to ./model\652-0.0651.hdf5
#
# Epoch 00653: val_loss did not improve from 0.06514
#
# Epoch 00654: val_loss did not improve from 0.06514
#
# Epoch 00655: val_loss did not improve from 0.06514
#
# Epoch 00656: val_loss did not improve from 0.06514
#
# Epoch 00657: val_loss did not improve from 0.06514
#
# Epoch 00658: val_loss did not improve from 0.06514
#
# Epoch 00659: val_loss did not improve from 0.06514
#
# Epoch 00660: val_loss did not improve from 0.06514
#
# Epoch 00661: val_loss did not improve from 0.06514
#
# Epoch 00662: val_loss improved from 0.06514 to 0.06499, saving model to ./model\662-0.0650.hdf5
#
# Epoch 00663: val_loss improved from 0.06499 to 0.06437, saving model to ./model\663-0.0644.hdf5
#
# Epoch 00664: val_loss did not improve from 0.06437
#
# Epoch 00665: val_loss did not improve from 0.06437
#
# Epoch 00666: val_loss did not improve from 0.06437
#
# Epoch 00667: val_loss did not improve from 0.06437
#
# Epoch 00668: val_loss did not improve from 0.06437
#
# Epoch 00669: val_loss did not improve from 0.06437
#
# Epoch 00670: val_loss improved from 0.06437 to 0.06407, saving model to ./model\670-0.0641.hdf5
#
# Epoch 00671: val_loss improved from 0.06407 to 0.06392, saving model to ./model\671-0.0639.hdf5
#
# Epoch 00672: val_loss did not improve from 0.06392
#
# Epoch 00673: val_loss did not improve from 0.06392
#
# Epoch 00674: val_loss did not improve from 0.06392
#
# ...
#
# Epoch 02437: val_loss did not improve from 0.03817
#
# Epoch 02438: val_loss did not improve from 0.03817
#
# Epoch 02439: val_loss did not improve from 0.03817
#
# Epoch 02440: val_loss did not improve from 0.03817
#
# Epoch 02441: val_loss did not improve from 0.03817
#
# Epoch 02442: val_loss did not improve from 0.03817
#
# Epoch 02443: val_loss did not improve from 0.03817
#
# Epoch 02444: val_loss did not improve from 0.03817
#
# Epoch 02445: val_loss did not improve from 0.03817
#
# Epoch 02446: val_loss did not improve from 0.03817
#
# Epoch 02447: val_loss did not improve from 0.03817
#
# Epoch 02448: val_loss did not improve from 0.03817
#
# Epoch 02449: val_loss did not improve from 0.03817
#
# Epoch 02450: val_loss did not improve from 0.03817
#
# Epoch 02451: val_loss did not improve from 0.03817
#
# Epoch 02452: val_loss did not improve from 0.03817
#
# Epoch 02453: val_loss did not improve from 0.03817
#
# Epoch 02454: val_loss did not improve from 0.03817
#
# Epoch 02455: val_loss did not improve from 0.03817
#
# Epoch 02456: val_loss did not improve from 0.03817
#
# Epoch 02457: val_loss did not improve from 0.03817
#
# Epoch 02458: val_loss did not improve from 0.03817
#
# Epoch 02459: val_loss did not improve from 0.03817
#
# Epoch 02460: val_loss improved from 0.03817 to 0.03816, saving model to ./model\2460-0.0382.hdf5
#
# Epoch 02461: val_loss did not improve from 0.03816
#
# Epoch 02462: val_loss did not improve from 0.03816
#
# Epoch 02463: val_loss did not improve from 0.03816
#
# Epoch 02464: val_loss did not improve from 0.03816
#
# Epoch 02465: val_loss did not improve from 0.03816
#
# Epoch 02466: val_loss did not improve from 0.03816
#
# Epoch 02467: val_loss did not improve from 0.03816
#
# Epoch 02468: val_loss did not improve from 0.03816
#
# Epoch 02469: val_loss did not improve from 0.03816
#
# Epoch 02470: val_loss did not improve from 0.03816
#
# Epoch 02471: val_loss did not improve from 0.03816
#
# Epoch 02472: val_loss did not improve from 0.03816
#
# Epoch 02473: val_loss did not improve from 0.03816
#
# Epoch 02474: val_loss did not improve from 0.03816
#
# Epoch 02475: val_loss did not improve from 0.03816
#
# Epoch 02476: val_loss did not improve from 0.03816
#
# Epoch 02477: val_loss did not improve from 0.03816
#
# Epoch 02478: val_loss did not improve from 0.03816
#
# Epoch 02479: val_loss did not improve from 0.03816
#
# Epoch 02480: val_loss did not improve from 0.03816
#
# Epoch 02481: val_loss improved from 0.03816 to 0.03814, saving model to ./model\2481-0.0381.hdf5
#
# Epoch 02482: val_loss did not improve from 0.03814
#
# Epoch 02483: val_loss did not improve from 0.03814
#
# Epoch 02484: val_loss did not improve from 0.03814
#
# Epoch 02485: val_loss did not improve from 0.03814
#
# Epoch 02486: val_loss did not improve from 0.03814
#
# Epoch 02487: val_loss did not improve from 0.03814
#
# Epoch 02488: val_loss did not improve from 0.03814
#
# Epoch 02489: val_loss improved from 0.03814 to 0.03812, saving model to ./model\2489-0.0381.hdf5
#
# Epoch 02490: val_loss improved from 0.03812 to 0.03809, saving model to ./model\2490-0.0381.hdf5
#
# Epoch 02491: val_loss did not improve from 0.03809
#
# Epoch 02492: val_loss did not improve from 0.03809
# Epoch 02493: val_loss did not improve from 0.03809
#
# Epoch 02494: val_loss did not improve from 0.03809
#
# Epoch 02495: val_loss did not improve from 0.03809
#
# Epoch 02496: val_loss did not improve from 0.03809
#
# Epoch 02497: val_loss did not improve from 0.03809
#
# Epoch 02498: val_loss did not improve from 0.03809
#
# Epoch 02499: val_loss did not improve from 0.03809
#
# Epoch 02500: val_loss did not improve from 0.03809
#
# Epoch 02501: val_loss did not improve from 0.03809
#
# Epoch 02502: val_loss did not improve from 0.03809
#
# Epoch 02503: val_loss did not improve from 0.03809
#
# Epoch 02504: val_loss did not improve from 0.03809
#
# Epoch 02505: val_loss did not improve from 0.03809
#
# Epoch 02506: val_loss did not improve from 0.03809
#
# Epoch 02507: val_loss improved from 0.03809 to 0.03808, saving model to ./model\2507-0.0381.hdf5
#
# Epoch 02508: val_loss did not improve from 0.03808
#
# Epoch 02509: val_loss did not improve from 0.03808
#
# Epoch 02510: val_loss did not improve from 0.03808
#
# Epoch 02511: val_loss did not improve from 0.03808
#
# Epoch 02512: val_loss did not improve from 0.03808
#
# Epoch 02513: val_loss did not improve from 0.03808
#
# Epoch 02514: val_loss did not improve from 0.03808
#
# Epoch 02515: val_loss did not improve from 0.03808
#
# Epoch 02516: val_loss did not improve from 0.03808
#
# Epoch 02517: val_loss did not improve from 0.03808
#
# Epoch 02518: val_loss did not improve from 0.03808
#
# Epoch 02519: val_loss did not improve from 0.03808
#
# Epoch 02520: val_loss did not improve from 0.03808
#
# Epoch 02521: val_loss did not improve from 0.03808
#
# Epoch 02522: val_loss did not improve from 0.03808
#
# Epoch 02523: val_loss did not improve from 0.03808
#
# Epoch 02524: val_loss did not improve from 0.03808
#
# Epoch 02525: val_loss did not improve from 0.03808
#
# Epoch 02526: val_loss did not improve from 0.03808
#
# Epoch 02527: val_loss did not improve from 0.03808
#
# Epoch 02528: val_loss did not improve from 0.03808
#
# Epoch 02529: val_loss did not improve from 0.03808
#
# Epoch 02530: val_loss did not improve from 0.03808
#
# Epoch 02531: val_loss did not improve from 0.03808
#
# Epoch 02532: val_loss did not improve from 0.03808
#
# Epoch 02533: val_loss did not improve from 0.03808
#
# Epoch 02534: val_loss did not improve from 0.03808
#
# Epoch 02535: val_loss did not improve from 0.03808
#
# Epoch 02536: val_loss did not improve from 0.03808
#
# Epoch 02537: val_loss did not improve from 0.03808
#
# Epoch 02538: val_loss did not improve from 0.03808
#
# Epoch 02539: val_loss did not improve from 0.03808
#
# Epoch 02540: val_loss did not improve from 0.03808
#
# Epoch 02541: val_loss improved from 0.03808 to 0.03808, saving model to ./model\2541-0.0381.hdf5
#
# Epoch 02542: val_loss did not improve from 0.03808
#
# Epoch 02543: val_loss did not improve from 0.03808
#
# Epoch 02544: val_loss did not improve from 0.03808
#
# Epoch 02545: val_loss did not improve from 0.03808
#
# Epoch 02546: val_loss did not improve from 0.03808
#
# Epoch 02547: val_loss did not improve from 0.03808
#
# Epoch 02548: val_loss did not improve from 0.03808
#
# Epoch 02549: val_loss did not improve from 0.03808
#
# Epoch 02550: val_loss did not improve from 0.03808
#
# Epoch 02551: val_loss did not improve from 0.03808
#
# Epoch 02552: val_loss did not improve from 0.03808
#
# Epoch 02553: val_loss improved from 0.03808 to 0.03808, saving model to ./model\2553-0.0381.hdf5
#
# Epoch 02554: val_loss did not improve from 0.03808
#
# Epoch 02555: val_loss did not improve from 0.03808
#
# Epoch 02556: val_loss did not improve from 0.03808
#
# Epoch 02557: val_loss did not improve from 0.03808
#
# Epoch 02558: val_loss did not improve from 0.03808
#
# Epoch 02559: val_loss did not improve from 0.03808
#
# Epoch 02560: val_loss did not improve from 0.03808
#
# Epoch 02561: val_loss did not improve from 0.03808
#
# Epoch 02562: val_loss did not improve from 0.03808
#
# Epoch 02563: val_loss improved from 0.03808 to 0.03806, saving model to ./model\2563-0.0381.hdf5
#
# Epoch 02564: val_loss improved from 0.03806 to 0.03804, saving model to ./model\2564-0.0380.hdf5
#
# Epoch 02565: val_loss did not improve from 0.03804
#
# Epoch 02566: val_loss did not improve from 0.03804
#
# Epoch 02567: val_loss did not improve from 0.03804
#
# Epoch 02568: val_loss did not improve from 0.03804
#
# Epoch 02569: val_loss did not improve from 0.03804
#
# Epoch 02570: val_loss did not improve from 0.03804
#
# Epoch 02571: val_loss did not improve from 0.03804
#
# Epoch 02572: val_loss did not improve from 0.03804
#
# Epoch 02573: val_loss did not improve from 0.03804
#
# Epoch 02574: val_loss did not improve from 0.03804
#
# Epoch 02575: val_loss improved from 0.03804 to 0.03803, saving model to ./model\2575-0.0380.hdf5
#
# Epoch 02576: val_loss improved from 0.03803 to 0.03802, saving model to ./model\2576-0.0380.hdf5
#
# Epoch 02577: val_loss did not improve from 0.03802
#
# Epoch 02578: val_loss did not improve from 0.03802
#
# Epoch 02579: val_loss did not improve from 0.03802
#
# Epoch 02580: val_loss did not improve from 0.03802
#
# Epoch 02581: val_loss did not improve from 0.03802
#
# Epoch 02582: val_loss did not improve from 0.03802
#
# Epoch 02583: val_loss did not improve from 0.03802
#
# Epoch 02584: val_loss did not improve from 0.03802
#
# Epoch 02585: val_loss did not improve from 0.03802
#
# Epoch 02586: val_loss did not improve from 0.03802
#
# Epoch 02587: val_loss did not improve from 0.03802
#
# Epoch 02588: val_loss did not improve from 0.03802
#
# Epoch 02589: val_loss did not improve from 0.03802
#
# Epoch 02590: val_loss did not improve from 0.03802
#
# Epoch 02591: val_loss did not improve from 0.03802
#
# Epoch 02592: val_loss did not improve from 0.03802
#
# Epoch 02593: val_loss did not improve from 0.03802
#
# Epoch 02594: val_loss did not improve from 0.03802
#
# Epoch 02595: val_loss did not improve from 0.03802
#
# Epoch 02596: val_loss did not improve from 0.03802
#
# Epoch 02597: val_loss did not improve from 0.03802
#
# Epoch 02598: val_loss did not improve from 0.03802
#
# Epoch 02599: val_loss did not improve from 0.03802
#
# Epoch 02600: val_loss did not improve from 0.03802
#
# Epoch 02601: val_loss did not improve from 0.03802
#
# Epoch 02602: val_loss did not improve from 0.03802
#
# Epoch 02603: val_loss did not improve from 0.03802
#
# Epoch 02604: val_loss did not improve from 0.03802
#
# Epoch 02605: val_loss did not improve from 0.03802
#
# Epoch 02606: val_loss improved from 0.03802 to 0.03802, saving model to ./model\2606-0.0380.hdf5
#
# Epoch 02607: val_loss did not improve from 0.03802
#
# Epoch 02608: val_loss did not improve from 0.03802
#
# Epoch 02609: val_loss did not improve from 0.03802
#
# Epoch 02610: val_loss did not improve from 0.03802
#
# Epoch 02611: val_loss did not improve from 0.03802
#
# Epoch 02612: val_loss did not improve from 0.03802
#
# Epoch 02613: val_loss did not improve from 0.03802
#
# Epoch 02614: val_loss did not improve from 0.03802
#
# Epoch 02615: val_loss did not improve from 0.03802
#
# Epoch 02616: val_loss did not improve from 0.03802
#
# Epoch 02617: val_loss did not improve from 0.03802
#
# Epoch 02618: val_loss did not improve from 0.03802
#
# Epoch 02619: val_loss did not improve from 0.03802
#
# Epoch 02620: val_loss did not improve from 0.03802
#
# Epoch 02621: val_loss did not improve from 0.03802
#
# Epoch 02622: val_loss did not improve from 0.03802
#
# Epoch 02623: val_loss did not improve from 0.03802
#
# Epoch 02624: val_loss did not improve from 0.03802
#
# Epoch 02625: val_loss did not improve from 0.03802
#
# Epoch 02626: val_loss did not improve from 0.03802
#
# Epoch 02627: val_loss did not improve from 0.03802
#
# Epoch 02628: val_loss did not improve from 0.03802
#
# Epoch 02629: val_loss did not improve from 0.03802
#
# Epoch 02630: val_loss improved from 0.03802 to 0.03801, saving model to ./model\2630-0.0380.hdf5
#
# Epoch 02631: val_loss improved from 0.03801 to 0.03798, saving model to ./model\2631-0.0380.hdf5
#
# Epoch 02632: val_loss did not improve from 0.03798
#
# Epoch 02633: val_loss did not improve from 0.03798
#
# Epoch 02634: val_loss did not improve from 0.03798
#
# Epoch 02635: val_loss did not improve from 0.03798
#
# Epoch 02636: val_loss did not improve from 0.03798
#
# Epoch 02637: val_loss did not improve from 0.03798
#
# Epoch 02638: val_loss did not improve from 0.03798
#
# Epoch 02639: val_loss did not improve from 0.03798
#
# Epoch 02640: val_loss did not improve from 0.03798
#
# Epoch 02641: val_loss did not improve from 0.03798
#
# Epoch 02642: val_loss did not improve from 0.03798
#
# Epoch 02643: val_loss did not improve from 0.03798
#
# Epoch 02644: val_loss did not improve from 0.03798
# Epoch 02645: val_loss did not improve from 0.03798
#
# Epoch 02646: val_loss did not improve from 0.03798
#
# Epoch 02647: val_loss did not improve from 0.03798
#
# Epoch 02648: val_loss did not improve from 0.03798
#
# Epoch 02649: val_loss did not improve from 0.03798
#
# Epoch 02650: val_loss did not improve from 0.03798
#
# Epoch 02651: val_loss did not improve from 0.03798
#
# Epoch 02652: val_loss did not improve from 0.03798
#
# Epoch 02653: val_loss did not improve from 0.03798
#
# Epoch 02654: val_loss did not improve from 0.03798
#
# Epoch 02655: val_loss did not improve from 0.03798
#
# Epoch 02656: val_loss did not improve from 0.03798
#
# Epoch 02657: val_loss did not improve from 0.03798
#
# Epoch 02658: val_loss did not improve from 0.03798
#
# Epoch 02659: val_loss did not improve from 0.03798
#
# Epoch 02660: val_loss did not improve from 0.03798
#
# Epoch 02661: val_loss did not improve from 0.03798
#
# Epoch 02662: val_loss did not improve from 0.03798
#
# Epoch 02663: val_loss did not improve from 0.03798
#
# Epoch 02664: val_loss did not improve from 0.03798
#
# Epoch 02665: val_loss did not improve from 0.03798
#
# Epoch 02666: val_loss did not improve from 0.03798
#
# Epoch 02667: val_loss did not improve from 0.03798
#
# Epoch 02668: val_loss did not improve from 0.03798
#
# Epoch 02669: val_loss did not improve from 0.03798
#
# Epoch 02670: val_loss did not improve from 0.03798
#
# Epoch 02671: val_loss did not improve from 0.03798
#
# Epoch 02672: val_loss did not improve from 0.03798
#
# Epoch 02673: val_loss did not improve from 0.03798
#
# Epoch 02674: val_loss did not improve from 0.03798
#
# Epoch 02675: val_loss did not improve from 0.03798
#
# Epoch 02676: val_loss did not improve from 0.03798
#
# Epoch 02677: val_loss did not improve from 0.03798
#
# Epoch 02678: val_loss did not improve from 0.03798
#
# Epoch 02679: val_loss did not improve from 0.03798
#
# Epoch 02680: val_loss did not improve from 0.03798
#
# Epoch 02681: val_loss did not improve from 0.03798
#
# Epoch 02682: val_loss did not improve from 0.03798
#
# Epoch 02683: val_loss did not improve from 0.03798
#
# Epoch 02684: val_loss did not improve from 0.03798
#
# Epoch 02685: val_loss did not improve from 0.03798
#
# Epoch 02686: val_loss did not improve from 0.03798
#
# Epoch 02687: val_loss did not improve from 0.03798
#
# Epoch 02688: val_loss did not improve from 0.03798
#
# Epoch 02689: val_loss did not improve from 0.03798
#
# Epoch 02690: val_loss did not improve from 0.03798
#
# Epoch 02691: val_loss did not improve from 0.03798
#
# Epoch 02692: val_loss did not improve from 0.03798
#
# Epoch 02693: val_loss did not improve from 0.03798
#
# Epoch 02694: val_loss did not improve from 0.03798
#
# Epoch 02695: val_loss did not improve from 0.03798
#
# Epoch 02696: val_loss did not improve from 0.03798
#
# Epoch 02697: val_loss did not improve from 0.03798
#
# Epoch 02698: val_loss did not improve from 0.03798
#
# Epoch 02699: val_loss did not improve from 0.03798
#
# Epoch 02700: val_loss did not improve from 0.03798
#
# Epoch 02701: val_loss did not improve from 0.03798
#
# Epoch 02702: val_loss did not improve from 0.03798
#
# Epoch 02703: val_loss did not improve from 0.03798
#
# Epoch 02704: val_loss did not improve from 0.03798
#
# Epoch 02705: val_loss did not improve from 0.03798
#
# Epoch 02706: val_loss did not improve from 0.03798
#
# Epoch 02707: val_loss did not improve from 0.03798
#
# Epoch 02708: val_loss did not improve from 0.03798
#
# Epoch 02709: val_loss did not improve from 0.03798
#
# Epoch 02710: val_loss did not improve from 0.03798
#
# Epoch 02711: val_loss did not improve from 0.03798
#
# Epoch 02712: val_loss did not improve from 0.03798
#
# Epoch 02713: val_loss did not improve from 0.03798
#
# Epoch 02714: val_loss did not improve from 0.03798
#
# Epoch 02715: val_loss did not improve from 0.03798
#
# Epoch 02716: val_loss did not improve from 0.03798
#
# Epoch 02717: val_loss did not improve from 0.03798
#
# Epoch 02718: val_loss did not improve from 0.03798
#
# Epoch 02719: val_loss did not improve from 0.03798
#
# Epoch 02720: val_loss did not improve from 0.03798
#
# Epoch 02721: val_loss did not improve from 0.03798
#
# Epoch 02722: val_loss did not improve from 0.03798
#
# Epoch 02723: val_loss did not improve from 0.03798
#
# Epoch 02724: val_loss did not improve from 0.03798
#
# Epoch 02725: val_loss did not improve from 0.03798
#
# Epoch 02726: val_loss did not improve from 0.03798
#
# Epoch 02727: val_loss did not improve from 0.03798
#
# Epoch 02728: val_loss did not improve from 0.03798
#
# Epoch 02729: val_loss did not improve from 0.03798
#
# Epoch 02730: val_loss did not improve from 0.03798
#
# Epoch 02731: val_loss did not improve from 0.03798

# %%
import matplotlib.pyplot as plt

# x값을 지정하고 정확도를 파란색으로, 오차를 빨간색으로 표시
x_len = numpy.arange(len(y_acc))
plt.plot(x_len, y_vloss, "o", c="red", markersize=3)
plt.plot(x_len, y_acc, "o", c="blue", markersize=3)
plt.plot(x_len, y_vacc, "o", c="yellow", markersize=3)

plt.show()
